# %% [markdown]
# # Enseignement Scientifique - Ecologie.
# ## Recenser des individus,
# ## la méthode de capture - marquage - recapture.

# %% [markdown]
# ### Problèmatique.
# Un étang habrite une population de poissons dont on veut estimer le nombre $N$. Comme il est impossible de recenser tous les individus de l'étang on utilise une méthode appelée *capture - marquage - recapture*.
#
# Cette méthode consiste à capturer un échantillon de taille $N_0$ de cette population et de marquer les individus.

# %%
import matplotlib.pyplot as plt

# %%
from random import randint, choice,shuffle

# %%
population = [  [randint(0,400), randint(0,400),'b']  for _ in range(size)] 
def dist(pos) : return pos[0]**2 + pos[1] **2
population.sort(key = dist)
for i in range(50) : population[i][2] = 'r'

# %%
plt.scatter([v[0] for v in population], [v[1] for v in population],c = [v[2] for v in population])

# %%
for poisson in population :
    poisson[0],poisson[1] = randint(0,400),randint(0,400)

# %%
plt.scatter([v[0] for v in population], [v[1] for v in population],c = [v[2] for v in population])

# %%
from population import *

# %%
population = genere()

# %%
represente(population)

# %%
capture(population,100)

# %%
represente(population)

# %%
melange(population)

# %%
represente(population)
